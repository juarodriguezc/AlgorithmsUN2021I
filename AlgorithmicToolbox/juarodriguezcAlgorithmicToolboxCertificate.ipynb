# %% [markdown]
# # **Coursera Certificate**
# ##Algorithmic Toolbox – University of California San Diego – HSE Moscow (National Research University Higher School of Economics)
#
# Juan Sebastián Rodríguez Castellanos

# %% [markdown]
# ## Certificate image

# %% [markdown]
# **Imagen certificado:**
# <img src = "https://raw.githubusercontent.com/juarodriguezc/AlgorithmsUN2021I/master/AlgorithmicToolbox/coursera1.JPG">

# %% [markdown]
# ## Certificate linkedin

# %% [markdown]
# **Link del linkedin:** https://www.linkedin.com/in/juan-sebastian-rodriguez-castellanos-3b2a33208/

# %% [markdown]
# **Imagen del perfil:**
# <img src = "https://raw.githubusercontent.com/juarodriguezc/AlgorithmsUN2021I/master/AlgorithmicToolbox/lindekin1.JPG">

# %% [markdown]
# **Imagen certificado en perfil:**
#
# <img src = "https://raw.githubusercontent.com/juarodriguezc/AlgorithmsUN2021I/master/AlgorithmicToolbox/linkedin2.JPG">
