# %% [markdown]
# # LAB 9 Bubble Sort distribution - Bubble Sort distribution
#
# Rios García David Ricardo
#
# Rodríguez Castellanos Juan Sebastián

# %% [markdown]
# ## Optimized Bubble sort time complexity histograms for permutations of $n$ different elements
#
# ### **Best case** - increasingly sorted array (${n-1}$ comparisons + $0$ swaps) - $t_b(n) = n-1 = \Theta(n) $
#
# ### **Worst case** - decreasingly sorted array ($\frac{n^2-n}{2}$ comparisons + $\frac{n^2-n}{2}$  swaps) - $t_w(n) = n^2-n = \Theta(n^2) $
#
# ### **Average case** - expected number of comparisons + swaps on random unifrom permutation of $n$ different elements $t_a(n) = \frac{454693}{621314}n^2 - \frac{729350}{568183}n + \frac{733625}{820457}= \Theta(n^2) $

# %%
from itertools import product

n=3 
perm = product(range(1,n+1), repeat = n)

c=0
for i in perm:
    print(i)
    c+=1

print(c)
# Out:
# (1, 1, 1)
# (1, 1, 2)
# (1, 1, 3)
# (1, 2, 1)
# (1, 2, 2)
# (1, 2, 3)
# (1, 3, 1)
# (1, 3, 2)
# (1, 3, 3)
# (2, 1, 1)
# (2, 1, 2)
# (2, 1, 3)
# (2, 2, 1)
# (2, 2, 2)
# (2, 2, 3)
# (2, 3, 1)
# (2, 3, 2)
# (2, 3, 3)
# (3, 1, 1)
# (3, 1, 2)
# (3, 1, 3)
# (3, 2, 1)
# (3, 2, 2)
# (3, 2, 3)
# (3, 3, 1)
# (3, 3, 2)
# (3, 3, 3)
# 27

# %%
def OptibubbleSort(arr):
  steps = 0
  n = len(arr)
  # Traverse through all array elements
  for i in range(n):
    #Set swap to false
    swap = False
    # Last i elements are already in place
    for j in range(0, n-i-1):
      # traverse the array from 0 to n-i-1
      # Swap if the element found is greater
      # than the next element
      steps +=1
      if arr[j] > arr[j+1] :
        arr[j], arr[j+1] = arr[j+1], arr[j]
        steps +=1
        #Si hay almenos un swap entonces swap = True
        swap = True
    #Si en el ciclo no hubo swap entonces salir
    if (swap == False):
      return(steps)
  return(steps)

# %%
from itertools import product
import matplotlib.pyplot as plt
import numpy as np 

n = 3
perm = product(range(1,n+1), repeat = n)

times =  [] 
# Print the obtained permutations
for i in list(perm):
    i = list(i)
    times.append(OptibubbleSort(i))

b = np.array(range(min(times)-1,max(times)+2) ) +0.5
plt.hist(times,bins=b)
plt.title("Optimized Bubble Sort")
plt.xlabel("Steps = comparisons + swaps ")
plt.ylabel("Frequency")
plt.show()
    
print("n",n)  
print("number of permutations ,n**n = ",n**n)
print("exp min =",min(times))
print("min formula (n-1) =",(n-1))
print("exp max =",max(times))
print("max formula (n-1)*n =",(n-1)*n)
print("exp mean =",np.mean(times))
print("mean formula  454693/621314 *n**2 + -729350/568183 *n + 733625/820457 =", 454693/621314 *n**2 + -729350/568183 *n + 733625/820457)
print("stdev",np.std(times))
# Out:
# n 3
# number of permutations ,n**n =  27
# exp min = 2
# min formula (n-1) = 2
# exp max = 6
# max formula (n-1)*n = 6
# exp mean = 3.6296296296296298
# mean formula  454693/621314 *n**2 + -729350/568183 *n + 733625/820457 = 3.6296295999929518
# stdev 1.3374422285383547

# %%
from itertools import product
import matplotlib.pyplot as plt
import numpy as np 

n = 4
perm = product(range(1,n+1), repeat = n)

times =  [] 
# Print the obtained permutations
for i in list(perm):
    i = list(i)
    times.append(OptibubbleSort(i))

b = np.array(range(min(times)-1,max(times)+2) ) +0.5
plt.hist(times,bins=b)
plt.title("Optimized Bubble Sort")
plt.xlabel("Steps = comparisons + swaps ")
plt.ylabel("Frequency")
plt.show()
    
print("n",n)  
print("number of permutations ,n**n = ",n**n)
print("exp min =",min(times))
print("min formula (n-1) =",(n-1))
print("exp max =",max(times))
print("max formula (n-1)*n =",(n-1)*n)
print("exp mean =",np.mean(times))
print("mean formula  454693/621314 *n**2 + -729350/568183 *n + 733625/820457 =", 454693/621314 *n**2 + -729350/568183 *n + 733625/820457)
print("stdev",np.std(times))
# Out:
# n 4
# number of permutations ,n**n =  256
# exp min = 3
# min formula (n-1) = 3
# exp max = 12
# max formula (n-1)*n = 12
# exp mean = 7.46875
# mean formula  454693/621314 *n**2 + -729350/568183 *n + 733625/820457 = 7.468749939988047
# stdev 2.2995838618106537

# %%
from itertools import product
import matplotlib.pyplot as plt
import numpy as np 

n = 5
perm = product(range(1,n+1), repeat = n)

times =  [] 
# Print the obtained permutations
for i in list(perm):
    i = list(i)
    times.append(OptibubbleSort(i))

b = np.array(range(min(times)-1,max(times)+2) ) +0.5
plt.hist(times,bins=b)
plt.title("Optimized Bubble Sort")
plt.xlabel("Steps = comparisons + swaps ")
plt.ylabel("Frequency")
plt.show()
    
print("n",n)  
print("number of permutations ,n**n = ",n**n)
print("exp min =",min(times))
print("min formula (n-1) =",(n-1))
print("exp max =",max(times))
print("max formula (n-1)*n =",(n-1)*n)
print("exp mean =",np.mean(times))
print("mean formula  454693/621314 *n**2 + -729350/568183 *n + 733625/820457 =", 454693/621314 *n**2 + -729350/568183 *n + 733625/820457)
print("stdev",np.std(times))
# Out:
# n 5
# number of permutations ,n**n =  3125
# exp min = 4
# min formula (n-1) = 4
# exp max = 20
# max formula (n-1)*n = 20
# exp mean = 12.77152
# mean formula  454693/621314 *n**2 + -729350/568183 *n + 733625/820457 = 12.771519899982046
# stdev 3.2691951440071607

# %%
from itertools import product
import matplotlib.pyplot as plt
import numpy as np 

n = 6
perm = product(range(1,n+1), repeat = n)

times =  [] 
# Print the obtained permutations
for i in list(perm):
    i = list(i)
    times.append(OptibubbleSort(i))

b = np.array(range(min(times)-1,max(times)+2) ) +0.5
plt.hist(times,bins=b)
plt.title("Optimized Bubble Sort")
plt.xlabel("Steps = comparisons + swaps ")
plt.ylabel("Frequency")
plt.show()
    
print("n",n)  
print("number of permutations ,n**n = ",n**n)
print("exp min =",min(times))
print("min formula (n-1) =",(n-1))
print("exp max =",max(times))
print("max formula (n-1)*n =",(n-1)*n)
print("exp mean =",np.mean(times))
print("mean formula  454693/621314 *n**2 + -729350/568183 *n + 733625/820457 =", 454693/621314 *n**2 + -729350/568183 *n + 733625/820457)
print("stdev",np.std(times))
# Out:
# n 6
# number of permutations ,n**n =  46656
# exp min = 5
# min formula (n-1) = 5
# exp max = 30
# max formula (n-1)*n = 30
# exp mean = 19.52895661865569
# mean formula  454693/621314 *n**2 + -729350/568183 *n + 733625/820457 = 19.537939479974956
# stdev 4.290252772629642

# %%
from itertools import product
import matplotlib.pyplot as plt
import numpy as np 

n = 7 
perm = product(range(1,n+1), repeat = n)

times =  [] 
# Print the obtained permutations
for i in list(perm):
    i = list(i)
    times.append(OptibubbleSort(i))

b = np.array(range(min(times)-1,max(times)+2) ) +0.5
plt.hist(times,bins=b)
plt.title("Optimized Bubble Sort")
plt.xlabel("Steps = comparisons + swaps ")
plt.ylabel("Frequency")
plt.show()
    
print("n",n)  
print("number of permutations ,n**n = ",n**n)
print("exp min =",min(times))
print("min formula (n-1) =",(n-1))
print("exp max =",max(times))
print("max formula (n-1)*n =",(n-1)*n)
print("exp mean =",np.mean(times))
print("mean formula  454693/621314 *n**2 + -729350/568183 *n + 733625/820457 =", 454693/621314 *n**2 + -729350/568183 *n + 733625/820457)
print("stdev",np.std(times))
# Out:
# n 7
# number of permutations ,n**n =  823543
# exp min = 6
# min formula (n-1) = 6
# exp max = 42
# max formula (n-1)*n = 42
# exp mean = 27.74813215581943
# mean formula  454693/621314 *n**2 + -729350/568183 *n + 733625/820457 = 27.768008679966762
# stdev 5.373187736730251

# %%
from itertools import product
import matplotlib.pyplot as plt
import numpy as np 

n = 8
perm = product(range(1,n+1), repeat = n)

times =  [] 
# Print the obtained permutations
for i in list(perm):
    i = list(i)
    times.append(OptibubbleSort(i))

b = np.array(range(min(times)-1,max(times)+2) ) +0.5
plt.hist(times,bins=b)
plt.title("Optimized Bubble Sort")
plt.xlabel("Steps = comparisons + swaps ")
plt.ylabel("Frequency")
plt.show()
    
print("n",n)  
print("number of permutations ,n**n = ",n**n)
print("exp min =",min(times))
print("min formula (n-1) =",(n-1))
print("exp max =",max(times))
print("max formula (n-1)*n =",(n-1)*n)
print("exp mean =",np.mean(times))
print("mean formula  454693/621314 *n**2 + -729350/568183 *n + 733625/820457 =", 454693/621314 *n**2 + -729350/568183 *n + 733625/820457)
print("stdev",np.std(times))
# Out:
# n 8
# number of permutations ,n**n =  16777216
# exp min = 7
# min formula (n-1) = 7
# exp max = 56
# max formula (n-1)*n = 56
# exp mean = 37.4370551109314
# mean formula  454693/621314 *n**2 + -729350/568183 *n + 733625/820457 = 37.46172749995748
# stdev 6.511226704934139

# %%
from itertools import product
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import random 

fig = plt.figure()
ax = plt.axes(projection="3d")

N = 8

x = []
y = []
z = []
dx = []
dy = []
dz = []

for n in np.arange(3,N+1,1):
   A = range(n)
   times = []

   for P in  product(A, repeat = n):
       t = OptibubbleSort(list(P)) 
       times.append(t)  
 
   b = np.array(range(min(times)-1, max(times)+1))+0.5
   H = np.array(np.histogram(times,b))
   H[0] = H[0]/np.sum(H[0])
   for i in range(len(H[0])):
     x.append(n)
     y.append(H[1][i])
     z.append(0)
     dx.append(0.1)
     dy.append(0.1)
     dz.append(H[0][i])

ax.bar3d(x, y, z, dx, dy, dz, color='aqua', zsort='average')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
from itertools import product
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import random 

fig = plt.figure()
ax = plt.axes(projection="3d")

N = 8

x = []
y = []
z = []
dx = []
dy = []
dz = []

for n in np.arange(3,N+1,1):
   A = range(n)
   times = []

   for P in  product(A, repeat = n):
       t = OptibubbleSort(list(P)) 
       times.append(t)  
 
   b = np.array(range(min(times)-1, max(times)+1))+0.5
   H = np.array(np.histogram(times,b))
   H[0] = H[0]/np.sum(H[0])
   for i in range(len(H[0])):
     x.append(n)
     y.append(H[1][i])
     z.append(0)
     dx.append(0.1)
     dy.append(0.1)
     dz.append(H[0][i])

ax.view_init(30, 15)
ax.bar3d(x, y, z, dx, dy, dz, color='aqua', zsort='average')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %% [markdown]
# # Average case - expected number of comparisons + swaps on random unifrom permtation of $n$   elements with repetitions $t_a(n) = \frac{454693}{621314}n^2 - \frac{729350}{568183}n + \frac{733625}{820457}= \Theta(n^2) $

# %%
# Average case on random unifrom permutation of $n$ elements with repetitions $t_a(n) = \frac{3}{4}n^2 - n +\frac{1}{4}= \Theta(n^2) $
import numpy as np 
import pandas as pd
import scipy.linalg as la

n = np.array([3.0,4.0,5.0])    # Number n of sorted elments 
t = np.array([3.6296296296296298 ,7.46875, 12.77152]) # Average comparisons + swaps for the corresponding n 

data = pd.DataFrame({'n': n, 't': t})
data
# Out:
#      n         t
# 0  3.0   3.62963
# 1  4.0   7.46875
# 2  5.0  12.77152

# %%
# Interpolating a polynomial of degree 2

X = np.column_stack([n**0,n**1,n**2])
a = la.solve(X,t)
a
# Out:
# array([ 0.8941663 , -1.28365333,  0.73182481])

# %%
from fractions import Fraction

print("n**0: ",Fraction(0.8941663).limit_denominator())
print("n**1: ",Fraction(-1.28365333).limit_denominator())
print("n**2 ",Fraction(0.73182481).limit_denominator())

print("mean formula: ",Fraction(0.73182481).limit_denominator(),"*n**2 +",Fraction(-1.28365333).limit_denominator(),"*n +",Fraction(0.8941663 ).limit_denominator())
# Out:
# n**0:  733625/820457
# n**1:  -729350/568183
# n**2  454693/621314
# mean formula:  454693/621314 *n**2 + -729350/568183 *n + 733625/820457

# %%
n = np.arange(1,21,1)
plt.plot(n,  454693/621314 *n**2 + -729350/568183 *n + 733625/820457  ,color='blue')
